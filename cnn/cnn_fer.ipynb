# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Hyperparameters

# %%
TRAIN_SIZE = 0.80
BATCH_SIZE = 32
EPOCHS = 50

# %% [markdown]
# # Data Loading

# %% [markdown]
# Labels in data are integers. Define a map to interpret the labels.

# %%
class_names = ['Anger', 'Disgust', 'Fear', 'Happiness', 'Sadness', 'Surprise', 'Neutral']
n_classes = len(class_names)

# %% [markdown]
# Parse the csv file and save image arrays to X, and labels to Y.

# %%
data_path = "../large_data/fer/fer2013.csv"
handle = open(data_path)
first_row = True
X = []
Y = []
for row in handle:
    if first_row:
        first_row = False
    else:
        row = row.split(",")
        Y.append(int(row[0]))
        X.append([int(p) for p in row[1].split()])
X = np.array(X)
Y = np.array(Y)

n = X.shape[0]
n_pixels = X.shape[1]
print("Number of images: %d" % n)
print("Number of pixels: %d" % n_pixels)
# Out:
# Number of images: 35887
# Number of pixels: 2304

# %% [markdown]
# Input image arrays are flattened. Reshape to 2D, and add extra dimension for color channel (one, being it grey scale).

# %%
IMG_SHAPE = int(np.sqrt(n_pixels))  # 48x48 pixels
X = X.reshape((X.shape[0], IMG_SHAPE, IMG_SHAPE, 1))
X.shape
# Out:
# (35887, 48, 48, 1)

# %% [markdown]
# Check that number of integer labels is consistent with number of given classes.

# %%
assert(len(np.unique(Y)) == n_classes)

# %% [markdown]
# ### Split into train and validation sets

# %% [markdown]
# Shuffle X and Y in unison.

# %%
np.random.seed(1234)
idx = np.random.permutation(n)
X_shuffled = X[idx]
Y_shuffled = Y[idx]

# %% [markdown]
# Split into train and test.

# %%
n_train = int(n*TRAIN_SIZE)
n_test = n - n_train
Xtrain = X_shuffled[:n_train]
Xtest = X_shuffled[n_train:]
Ytrain = Y_shuffled[:n_train]
Ytest = Y_shuffled[n_train:]

# %% [markdown]
# # Data Pipeline Preparation

# %% [markdown]
# Define the generators to handle the train and test data pipelines. For train, include image augmentation techniques to reduce overfitting.

# %%
gen_train = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

gen_test = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# Use the generators to create the data pipelines. Shuffle train data at the beginning of each new epoch.

# %%
data_train = gen_train.flow(Xtrain, Ytrain,
                            batch_size=BATCH_SIZE,
                            shuffle=True)

data_test = gen_test.flow(Xtest, Ytest,
                          batch_size=BATCH_SIZE)

# %% [markdown]
# ## Visualize images

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(batch, n=5):
    cls = ['Anger', 'Disgust', 'Fear', 'Happiness', 'Sadness', 'Surprise', 'Neutral']
    n_cols = 5
    n_rows = 1 + (n - 1) // n_cols
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(20,20))
    axes = axes.reshape(n_rows, n_cols)
    images = batch[0][:n]
    labels = batch[1][:n]
    for i, img in enumerate(images):
        ax = axes[i // n_cols, i % n_cols]
        ax.imshow(img.reshape(IMG_SHAPE, IMG_SHAPE), cmap='gray')
        ax.set_title(cls[labels[i]])
    plt.tight_layout()
    plt.show()

# %%
plotImages(next(data_train), n=30)  # Plot images from current batch

# %% [markdown]
# # Basic CNN model

# %%
model = tf.keras.Sequential([
    
    tf.keras.layers.Conv2D(8, kernel_size=(3,3), padding='same', activation='relu', input_shape=(IMG_SHAPE, IMG_SHAPE, 1)),
    tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
    
    tf.keras.layers.Conv2D(16, kernel_size=(3,3), padding='same', activation='relu', input_shape=(IMG_SHAPE, IMG_SHAPE, 1)),
    tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
    
    tf.keras.layers.Conv2D(32, kernel_size=(3,3), padding='same', activation='relu', input_shape=(IMG_SHAPE, IMG_SHAPE, 1)),
    tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
    
    tf.keras.layers.Conv2D(64, kernel_size=(3,3), padding='same', activation='relu', input_shape=(IMG_SHAPE, IMG_SHAPE, 1)),
    tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.2),
    
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    
    tf.keras.layers.Dense(n_classes, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 48, 48, 8)         80
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 24, 24, 8)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 24, 24, 16)        1168
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 12, 12, 16)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 12, 12, 32)        4640
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 6, 6, 32)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 6, 6, 64)          18496
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 576)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               147712
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 7)                 1799
# =================================================================
# Total params: 173,895
# Trainable params: 173,895
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %% [markdown]
# ### Find optimal learning rate

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.optimizer.get_config()
# Out:
# {'name': 'Adam',
#  'learning_rate': 0.001,
#  'decay': 0.0,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07,
#  'amsgrad': False}

# %%
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-3 * 10**(epoch / 30))
history = model.fit_generator(data_train,
                              epochs=EPOCHS,
                              callbacks=[lr_schedule])
# Out:
# Epoch 1/50
# 898/898 [==============================] - 64s 72ms/step - loss: 1.8023 - accuracy: 0.2501
# Epoch 2/50
# 898/898 [==============================] - 72s 80ms/step - loss: 1.7672 - accuracy: 0.2699
# Epoch 3/50
# 898/898 [==============================] - 68s 76ms/step - loss: 1.7242 - accuracy: 0.2951
# Epoch 4/50
# 898/898 [==============================] - 65s 73ms/step - loss: 1.6752 - accuracy: 0.3324
# Epoch 5/50
# 898/898 [==============================] - 65s 72ms/step - loss: 1.6208 - accuracy: 0.3594
# Epoch 6/50
# 898/898 [==============================] - 64s 71ms/step - loss: 1.5846 - accuracy: 0.3782
# Epoch 7/50
# 898/898 [==============================] - 64s 71ms/step - loss: 1.5537 - accuracy: 0.3902
# Epoch 8/50
# 898/898 [==============================] - 63s 71ms/step - loss: 1.5244 - accuracy: 0.4028
# Epoch 9/50
# 898/898 [==============================] - 64s 71ms/step - loss: 1.5099 - accuracy: 0.4135
# Epoch 10/50
# 898/898 [==============================] - 64s 71ms/step - loss: 1.4999 - accuracy: 0.4159
# Epoch 11/50
# 898/898 [==============================] - 65s 72ms/step - loss: 1.4878 - accuracy: 0.4221
# Epoch 12/50
# 898/898 [==============================] - 63s 70ms/step - loss: 1.4759 - accuracy: 0.4258
# Epoch 13/50
# 898/898 [==============================] - 63s 70ms/step - loss: 1.4729 - accuracy: 0.4291
# Epoch 14/50
# 898/898 [==============================] - 63s 70ms/step - loss: 1.4686 - accuracy: 0.4286
# Epoch 15/50
# 898/898 [==============================] - 62s 69ms/step - loss: 1.4685 - accuracy: 0.4284
# Epoch 16/50
# 898/898 [==============================] - 62s 69ms/step - loss: 1.4728 - accuracy: 0.4297
# Epoch 17/50
# 898/898 [==============================] - 63s 70ms/step - loss: 1.4839 - accuracy: 0.4248
# Epoch 18/50
# 898/898 [==============================] - 62s 69ms/step - loss: 1.4837 - accuracy: 0.4262
# Epoch 19/50
# 898/898 [==============================] - 62s 69ms/step - loss: 1.4981 - accuracy: 0.4159
# Epoch 20/50
# 898/898 [==============================] - 62s 70ms/step - loss: 1.5061 - accuracy: 0.4103
# Epoch 21/50
# 898/898 [==============================] - 63s 70ms/step - loss: 1.5231 - accuracy: 0.4074
# Epoch 22/50
# 898/898 [==============================] - 62s 70ms/step - loss: 1.5430 - accuracy: 0.3986
# Epoch 23/50
# 898/898 [==============================] - 63s 70ms/step - loss: 1.5505 - accuracy: 0.3940
# Epoch 24/50
# 898/898 [==============================] - 63s 70ms/step - loss: 1.5791 - accuracy: 0.3796
# Epoch 25/50
# 898/898 [==============================] - 62s 70ms/step - loss: 1.5962 - accuracy: 0.3697
# Epoch 26/50
# 898/898 [==============================] - 63s 70ms/step - loss: 1.6049 - accuracy: 0.3651
# Epoch 27/50
# 898/898 [==============================] - 63s 70ms/step - loss: 1.6444 - accuracy: 0.3457
# Epoch 28/50
# 898/898 [==============================] - 63s 70ms/step - loss: 1.6434 - accuracy: 0.3442
# Epoch 29/50
# 898/898 [==============================] - 62s 70ms/step - loss: 1.6719 - accuracy: 0.3271
# Epoch 30/50
# 898/898 [==============================] - 63s 70ms/step - loss: 1.7090 - accuracy: 0.3100
# Epoch 31/50
# 898/898 [==============================] - 63s 70ms/step - loss: 1.7470 - accuracy: 0.2873
# Epoch 32/50
# 898/898 [==============================] - 64s 71ms/step - loss: 1.7552 - accuracy: 0.2827
# Epoch 33/50
# 898/898 [==============================] - 66s 74ms/step - loss: 1.7926 - accuracy: 0.2607
# Epoch 34/50
# 898/898 [==============================] - 64s 71ms/step - loss: 1.8106 - accuracy: 0.2500
# Epoch 35/50
# 898/898 [==============================] - 64s 71ms/step - loss: 1.8116 - accuracy: 0.2513
# Epoch 36/50
# 898/898 [==============================] - 64s 72ms/step - loss: 1.8115 - accuracy: 0.2513
# Epoch 37/50
# 898/898 [==============================] - 64s 72ms/step - loss: 1.8119 - accuracy: 0.2513
# Epoch 38/50
# 898/898 [==============================] - 64s 71ms/step - loss: 1.8121 - accuracy: 0.2513
# Epoch 39/50
# 898/898 [==============================] - 64s 72ms/step - loss: 1.8123 - accuracy: 0.2513
# Epoch 40/50
# 898/898 [==============================] - 65s 72ms/step - loss: 1.8137 - accuracy: 0.2510
# Epoch 41/50
# 898/898 [==============================] - 65s 72ms/step - loss: 1.8125 - accuracy: 0.2513
# Epoch 42/50
# 898/898 [==============================] - 65s 72ms/step - loss: 1.8122 - accuracy: 0.2513
# Epoch 43/50
# 898/898 [==============================] - 65s 72ms/step - loss: 1.8128 - accuracy: 0.2513
# Epoch 44/50
# 898/898 [==============================] - 65s 72ms/step - loss: 1.8129 - accuracy: 0.2513
# Epoch 45/50
# 898/898 [==============================] - 65s 72ms/step - loss: 1.8138 - accuracy: 0.2513
# Epoch 46/50
# 898/898 [==============================] - 65s 72ms/step - loss: 1.8135 - accuracy: 0.2513
# Epoch 47/50
# 898/898 [==============================] - 65s 72ms/step - loss: 1.8139 - accuracy: 0.2513
# Epoch 48/50
# 898/898 [==============================] - 65s 72ms/step - loss: 1.8144 - accuracy: 0.2513
# Epoch 49/50
# 898/898 [==============================] - 65s 72ms/step - loss: 1.8142 - accuracy: 0.2513
# Epoch 50/50
# 898/898 [==============================] - 65s 72ms/step - loss: 1.8146 - accuracy: 0.2513

# %%
plt.semilogx(history.history["lr"], history.history["loss"])
plt.axis([1e-3, 1e-1, 0, 2])
# Out:
# [0.001, 0.1, 0, 2]

# %% [markdown]
# ### Train with early stopping

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.optimizer.get_config()
# Out:
# {'name': 'Adam',
#  'learning_rate': 0.001,
#  'decay': 0.0,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07,
#  'amsgrad': False}

# %%
history = model.fit_generator(data_train,
                              steps_per_epoch=int(np.ceil(n_train / BATCH_SIZE)),
                              validation_data=data_test,
                              validation_steps=int(np.ceil(n_test / BATCH_SIZE)),
                              epochs=EPOCHS,
                              callbacks=[tf.keras.callbacks.EarlyStopping(patience=10)])
# Out:
# Epoch 1/50
# 358/898 [==========>...................] - ETA: 39s - loss: 1.8119 - accuracy: 0.2502
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-100-c2551b2952ca> in <module>
#       4                               validation_steps=int(np.ceil(n_test / BATCH_SIZE)),
#       5                               epochs=EPOCHS,
# ----> 6                               callbacks=[tf.keras.callbacks.EarlyStopping(patience=10)])
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1295         shuffle=shuffle,
#    1296         initial_epoch=initial_epoch,
# -> 1297         steps_name='steps_per_epoch')
#    1298
#    1299   def evaluate_generator(self,
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     263
#     264       is_deferred = not model._is_compiled
# --> 265       batch_outs = batch_function(*batch_data)
#     266       if not isinstance(batch_outs, list):
#     267         batch_outs = [batch_outs]
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#     971       outputs = training_v2_utils.train_on_batch(
#     972           self, x, y=y, sample_weight=sample_weight,
# --> 973           class_weight=class_weight, reset_metrics=reset_metrics)
#     974       outputs = (outputs['total_loss'] + outputs['output_losses'] +
#     975                  outputs['metrics'])
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in train_on_batch(model, x, y, sample_weight, class_weight, reset_metrics)
#     262       y,
#     263       sample_weights=sample_weights,
# --> 264       output_loss_metrics=model._output_loss_metrics)
#     265
#     266   if reset_metrics:
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_eager.py in train_on_batch(model, inputs, targets, sample_weights, output_loss_metrics)
#     309           sample_weights=sample_weights,
#     310           training=True,
# --> 311           output_loss_metrics=output_loss_metrics))
#     312   if not isinstance(outs, list):
#     313     outs = [outs]
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_eager.py in _process_single_batch(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     250               output_loss_metrics=output_loss_metrics,
#     251               sample_weights=sample_weights,
# --> 252               training=training))
#     253       if total_loss is None:
#     254         raise ValueError('The model cannot be run '
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_eager.py in _model_loss(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     125     inputs = nest.map_structure(ops.convert_to_tensor, inputs)
#     126
# --> 127   outs = model(inputs, **kwargs)
#     128   outs = nest.flatten(outs)
#     129
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/sequential.py in call(self, inputs, training, mask)
#     254       if not self.built:
#     255         self._init_graph_network(self.inputs, self.outputs, name=self.name)
# --> 256       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     257
#     258     outputs = inputs  # handle the corner case where self.layers is empty
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/network.py in call(self, inputs, training, mask)
#     706     return self._run_internal_graph(
#     707         inputs, training=training, mask=mask,
# --> 708         convert_kwargs_to_constants=base_layer_utils.call_context().saving)
#     709
#     710   def compute_output_shape(self, input_shape):
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/network.py in _run_internal_graph(self, inputs, training, mask, convert_kwargs_to_constants)
#     858
#     859           # Compute outputs.
# --> 860           output_tensors = layer(computed_tensors, **kwargs)
#     861
#     862           # Update tensor_dict.
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/keras/layers/convolutional.py in call(self, inputs)
#     206           outputs = nn.bias_add(outputs, self.bias, data_format='NCHW')
#     207       else:
# --> 208         outputs = nn.bias_add(outputs, self.bias, data_format='NHWC')
#     209
#     210     if self.activation is not None:
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/ops/nn_ops.py in bias_add(value, bias, data_format, name)
#    2716       value = ops.convert_to_tensor(value, name="input")
#    2717       bias = ops.convert_to_tensor(bias, dtype=value.dtype, name="bias")
# -> 2718     return gen_nn_ops.bias_add(value, bias, data_format=data_format, name=name)
#    2719
#    2720
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_nn_ops.py in bias_add(value, bias, data_format, name)
#     740         _ctx._context_handle, _ctx._thread_local_data.device_name, "BiasAdd",
#     741         name, _ctx._post_execution_callbacks, value, bias, "data_format",
# --> 742         data_format)
#     743       return _result
#     744     except _core._FallbackException:
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py in handle(self)
#     511     return self._initializer_op
#     512
# --> 513   @property
#     514   def handle(self):
#     515     """The handle by which this variable can be accessed."""
#
# KeyboardInterrupt:

# %% [markdown]
# ### Loss and accuracy graphs

# %%
test_loss, test_accuracy = model.evaluate(data_test, steps=int(np.ceil(n_test/BATCH_SIZE)))
print('Accuracy on test dataset:', test_accuracy)
# Out:
# 225/225 [==============================] - 2s 9ms/step - loss: 1.2940 - accuracy: 0.5111
# Accuracy on test dataset: 0.5111452

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(history.epoch))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
i_batch = np.random.choice(int(np.ceil(n_test/BATCH_SIZE)))
i_img = np.random.choice(BATCH_SIZE)

label = data_test[i_batch][1][i_img]
pred  = model.predict_classes(data_test[i_batch][0])[i_img]

plt.imshow(data_test[i_batch][0][i_img][:,:,0], cmap='gray')
print(("CORRECT" if label == pred else "WRONG") + " (class: %s, prediction: %s)" % (class_names[label], class_names[pred]))
# Out:
# Class: Fear
# Prediction: Happiness

# %% [markdown]
# # CNN model with transfer learning

# %% [markdown]
# ### Import Mobilenet v2 pre-trained

# %% [markdown]
# We import the feature vector from Tensorflow Hub. The feature vector does not include the output layer, that we need to retrain on the specific data at hand.

# %%
# !pip install -p -U tensorflow_hub
import tensorflow_hub as hub

# %%
IMG_RES = 96  # input resolution expected by the imported model
URL = "https://tfhub.dev/google/imagenet/mobilenet_v2_050_96/feature_vector/4"
feature_extractor = hub.KerasLayer(handle=URL,
                                   input_shape=(IMG_RES, IMG_RES, 3),
                                   trainable=False)  # note that we do want to retrain it

# %% [markdown]
# ### Resize images and repeat preprocessing

# %% [markdown]
# The FER database consists of (grayscale) images of shape (48, 48, 1). Mobilenet expects images of shape (96, 96, 3). We need to resize and duplicate the single grayscale color channel into three RGB color channels of identical intensity. We use Tensorflow methods that conveniently accepts batches as input.

# %%
X_res = tf.image.grayscale_to_rgb(tf.image.resize(X_shuffled, size=(IMG_RES, IMG_RES)))
X_res.shape
# Out:
# TensorShape([35887, 96, 96, 3])

# %%
Xtrain_res = X_res[:n_train]
Xtest_res = X_res[n_train:]

data_train_res = gen_train.flow(Xtrain_res, Ytrain,
                            batch_size=BATCH_SIZE,
                            shuffle=True)

data_test_res = gen_test.flow(Xtest_res, Ytest,
                          batch_size=BATCH_SIZE)

# %% [markdown]
# ### Model with transfer learning

# %%
model2 = tf.keras.Sequential([
    feature_extractor,  # reused model
    tf.keras.layers.Dense(n_classes, activation='softmax')
])

model2.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
               loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])

model2.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer_3 (KerasLayer)   (None, 1280)              706224
# _________________________________________________________________
# dense_10 (Dense)             (None, 7)                 8967
# =================================================================
# Total params: 715,191
# Trainable params: 8,967
# Non-trainable params: 706,224
# _________________________________________________________________

# %% [markdown]
# We use early stopping to halt training when validation accuracy stops improving. We also select the weights that correspond to the best performing model.

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.01,
    patience=10,
    restore_best_weights=True)

# %%
history2 = model2.fit_generator(data_train_res,
                                validation_data=data_test_res,
                                epochs=EPOCHS,
                                callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 898/898 [==============================] - 358s 398ms/step - loss: 1.6116 - accuracy: 0.3757 - val_loss: 1.4859 - val_accuracy: 0.4278
# Epoch 2/50
# 898/898 [==============================] - 373s 416ms/step - loss: 1.5191 - accuracy: 0.4153 - val_loss: 1.4627 - val_accuracy: 0.4365
# Epoch 3/50
# 898/898 [==============================] - 366s 408ms/step - loss: 1.4920 - accuracy: 0.4291 - val_loss: 1.4568 - val_accuracy: 0.4398
# Epoch 4/50
# 898/898 [==============================] - 372s 414ms/step - loss: 1.4819 - accuracy: 0.4295 - val_loss: 1.4399 - val_accuracy: 0.4531
# Epoch 5/50
# 898/898 [==============================] - 369s 411ms/step - loss: 1.4753 - accuracy: 0.4359 - val_loss: 1.4346 - val_accuracy: 0.4609
# Epoch 6/50
# 898/898 [==============================] - 364s 405ms/step - loss: 1.4689 - accuracy: 0.4380 - val_loss: 1.4334 - val_accuracy: 0.4528
# Epoch 7/50
# 898/898 [==============================] - 379s 422ms/step - loss: 1.4563 - accuracy: 0.4415 - val_loss: 1.4258 - val_accuracy: 0.4531
# Epoch 8/50
# 898/898 [==============================] - 377s 420ms/step - loss: 1.4539 - accuracy: 0.4435 - val_loss: 1.4180 - val_accuracy: 0.4604
# Epoch 9/50
# 898/898 [==============================] - 377s 420ms/step - loss: 1.4567 - accuracy: 0.4442 - val_loss: 1.4903 - val_accuracy: 0.4469
# Epoch 10/50
# 898/898 [==============================] - 377s 419ms/step - loss: 1.4593 - accuracy: 0.4434 - val_loss: 1.4368 - val_accuracy: 0.4614
# Epoch 11/50
# 898/898 [==============================] - 378s 421ms/step - loss: 1.4515 - accuracy: 0.4464 - val_loss: 1.4576 - val_accuracy: 0.4437
# Epoch 12/50
# 898/898 [==============================] - 394s 439ms/step - loss: 1.4575 - accuracy: 0.4441 - val_loss: 1.4418 - val_accuracy: 0.4617
# Epoch 13/50
# 898/898 [==============================] - 383s 427ms/step - loss: 1.4504 - accuracy: 0.4473 - val_loss: 1.4548 - val_accuracy: 0.4529
# Epoch 14/50
# 898/898 [==============================] - 385s 428ms/step - loss: 1.4493 - accuracy: 0.4496 - val_loss: 1.4451 - val_accuracy: 0.4504

# %% [markdown]
# ### Loss and accuracy

# %%
test_loss, test_accuracy = model2.evaluate(data_test_res)
print('Accuracy on test dataset:', test_accuracy)
# Out:
# 225/225 [==============================] - 18s 78ms/step - loss: 1.4415 - accuracy: 0.4531
# Accuracy on test dataset: 0.453051

# %%
acc = history2.history['accuracy']
val_acc = history2.history['val_accuracy']

loss = history2.history['loss']
val_loss = history2.history['val_loss']

epochs_range = range(len(history2.epoch))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
i_batch = np.random.choice(int(np.ceil(n_test/BATCH_SIZE)))
i_img   = np.random.choice(BATCH_SIZE)

label = data_test_res[i_batch][1][i_img]
pred  = model2.predict_classes(data_test_res[i_batch][0])[i_img]

plt.imshow(data_test_res[i_batch][0][i_img])
print(("CORRECT" if label == pred else "WRONG") + " (class: %s, prediction: %s)" % (class_names[label], class_names[pred]))
# Out:
# CORRECT (class: Neutral, prediction: Neutral)

# %% [markdown]
# ### Confusion matrix

# %%
import itertools

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = tf.math.reduce_max(cnf_matrix).numpy() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
pred=model2.predict_classes(Xtest_res)

# %%
# Generate the confusion matrix
cnf_matrix = tf.math.confusion_matrix(labels=Ytest, predictions=pred)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names)

plt.show()

# %% [markdown]
# Class imbalance?

# %%
{class_names[i]:sum(Ytrain==i) for i in range(n_classes)}
# Out:
# {'Anger': 3991,
#  'Disgust': 443,
#  'Fear': 4107,
#  'Happiness': 7214,
#  'Sadness': 4868,
#  'Surprise': 3167,
#  'Neutral': 4919}

# %% [markdown]
# Class 'Disgust' is seriously underrepresented, and class Happiness is overrrepresented. Otherwise, there is good balance.
